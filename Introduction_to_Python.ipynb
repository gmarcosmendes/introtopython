# %% [markdown]
# <a href="https://colab.research.google.com/github/gmarcosmendes/introtopython/blob/main/Introduction_to_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Trabalho de Introdução a Ciências da Computação**
#
# **Introdução a Python**
#
# **Aluno:** Gabriel Marcos Mendes
#
# **Professor:** Felipe Viel

# %% [markdown]
# **Gerando imagem normal sem alterações:**

# %%
from google.colab.patches import cv2_imshow
img = cv2.imread('t1.jpg',1)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=500x250 at 0x7FB58CE94150>

# %% [markdown]
# **Gerando a imagem em escala de cinza (preto e branco):**

# %%
B, G, R = cv2.split(img)
img_grayscale_pondered = 0.299*B+0.587*G+0.114*R

img_grayscale_pondered = np.array(img_grayscale_pondered, dtype=np.uint8)

cv2_imshow(img_grayscale_pondered)
# Out:
# <PIL.Image.Image image mode=L size=500x250 at 0x7FB579B58850>

# %% [markdown]
# **Gerando a imagem em negativo:**

# %%
img_in = cv2.imread('t1.jpg',1)

a = -1 
b = 1

img_out = a*img_in + b

img_out = np.array(img_out, dtype = np.uint8)

cv2_imshow(img_out)
# Out:
# <PIL.Image.Image image mode=RGB size=500x250 at 0x7FB57800F390>

# %% [markdown]
# **Gerando imagem com suavização:**

# %%
img = cv2.imread('t1.jpg',1)

kernel = np.ones((5,5),np.float32)/25

img_out_1 = cv2.filter2D(img,-1,kernel)


cv2_imshow(img)
cv2_imshow(img_out_1)
# Out:
# <PIL.Image.Image image mode=RGB size=500x250 at 0x7FB578012850>
# <PIL.Image.Image image mode=RGB size=500x250 at 0x7FB578012A50>
